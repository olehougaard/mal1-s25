# %% [markdown]
# # Preamble

# %%
import numpy as np

import matplotlib.pyplot as plt
import math

# %%
X = (np.arange(0, 200, 2) * .1)
mean = 10
sigma = 4
y = [1 / (2*math.pi*sigma**2) * math.exp(-math.pow(x - mean, 2)/(2 * sigma**2)) for x in X]
plt.plot(X, y)

# %%
X_prime = 5 * X - 20
plt.plot(X_prime, y)

# %%
plt.boxplot(X, vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15f7418c310>,
#   <matplotlib.lines.Line2D at 0x15f7418ce90>],
#  'caps': [<matplotlib.lines.Line2D at 0x15f7418d9d0>,
#   <matplotlib.lines.Line2D at 0x15f7418e4d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15f7417f790>],
#  'medians': [<matplotlib.lines.Line2D at 0x15f7418f050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15f7418fa10>],
#  'means': []}

# %%
X_exp = [math.pow(1.5, t) for t in X]
plt.plot(X_exp, y[:len(X_exp)])

# %%
X_sq = [t**2 for t in X]
plt.plot(X_sq, y)

# %%
plt.boxplot(X_sq, vert = False, showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15f7742b850>,
#   <matplotlib.lines.Line2D at 0x15f77438290>],
#  'caps': [<matplotlib.lines.Line2D at 0x15f77438d90>,
#   <matplotlib.lines.Line2D at 0x15f77439650>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15f7742ac10>],
#  'medians': [<matplotlib.lines.Line2D at 0x15f7743a190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15f7743b5d0>],
#  'means': [<matplotlib.lines.Line2D at 0x15f773fe550>]}

# %%
X_sqrt = [math.sqrt(t) for t in X]
plt.plot(X_sqrt, y)

# %%
plt.boxplot(X_sqrt, vert = False, showmeans=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15f775140d0>,
#   <matplotlib.lines.Line2D at 0x15f77514cd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x15f77515710>,
#   <matplotlib.lines.Line2D at 0x15f77516150>],
#  'boxes': [<matplotlib.lines.Line2D at 0x15f775033d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x15f77516c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x15f774b0190>],
#  'means': [<matplotlib.lines.Line2D at 0x15f775176d0>]}

# %%
X_log = [math.log(t) for t in X if t > 0]
plt.plot(X_log, y[1:])

# %%
from sklearn.datasets import make_circles
from matplotlib.colors import ListedColormap

colors = ListedColormap(['green', 'magenta', 'yellow', 'blue'])

X_circles, y_circles = make_circles(n_samples=300, factor=.4, noise = .08)
plt.scatter(X_circles[:, 0], X_circles[:, 1], c=y_circles, cmap=colors)

# %%
def polar(p):
    x, y = p
    r = np.sqrt(x**2 + y**2)
    theta = np.arctan2(x, y)
    return [r, theta]

X_polar = np.array([polar(p) for p in X_circles])
plt.scatter(X_polar[:, 0], X_polar[:, 1], c=y_circles, cmap=colors)
