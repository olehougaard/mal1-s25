# %% [markdown]
# # Preamble
#
# importing

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

from sklearn.model_selection import train_test_split

from plot_utils import plot_probabilities

# %% [markdown]
# # Neural networks on non-linear data
#
# Some familiar datasets to see how neural networks handle them.

# %%
from sklearn.datasets import make_moons, make_circles

colors = ListedColormap(['green', 'magenta', 'yellow', 'blue'])

X_moons, y_moons = make_moons(n_samples=1000, noise = .2, random_state = 504)
X_circles, y_circles = make_circles(n_samples=1000, factor=.65, noise = .05, random_state = 504)

figure = plt.figure(figsize=(20, 10))

ax = figure.add_subplot(1, 2, 2, title='moons')
ax.scatter(X_moons[:, 0], X_moons[:, 1], c=y_moons, cmap=ListedColormap(['green', 'magenta']))

ax = figure.add_subplot(1, 2, 1, title='circles')
ax.scatter(X_circles[:, 0], X_circles[:, 1], c=y_circles, cmap=ListedColormap(['green', 'magenta']))

# %% [markdown]
# ### Circles
#
# Circles are the simplest of the two. Let's see if we can use a simple network.
#
# The code below creates one hidden layer and one output layer. The input layer gets created automatically when we give the hidden layer the input_dim attribute.
#
# The output layer is a single node with a sigmoid activation, since this is a binary classifier. Another popular choice for binary classifiers is to make two nodes with a softmax activation. There isn't much difference between the two approaches, but softmax is a real staple of modern neural networks.
#
# We're using the classic sigmoid activation function because it's the easiest to interpret.
#
# Note, the use of the Adam optimizer. Stochastic gradient descent does not converge.

# %%
import tensorflow as tf
from tensorflow.keras import layers

tf.random.set_seed(504)
ann1 = tf.keras.Sequential([
  layers.Dense(4, input_dim=2, activation="sigmoid"),
  layers.Dense(1, activation="sigmoid")])

ann1.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=.01), metrics=['accuracy'])
ann1.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 4)                 12
#
#  dense_23 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 17 (68.00 Byte)
# Trainable params: 17 (68.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(ann1, show_shapes=True)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_circles, y_circles, random_state=504)

ann1.fit(X_train, y_train, epochs=200, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/200
# 24/24 [==============================] - 1s 15ms/step - loss: 0.6975 - accuracy: 0.4920 - val_loss: 0.6979 - val_accuracy: 0.4600
# Epoch 2/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6947 - accuracy: 0.4667 - val_loss: 0.6942 - val_accuracy: 0.3840
# Epoch 3/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6943 - accuracy: 0.4987 - val_loss: 0.6952 - val_accuracy: 0.4600
# Epoch 4/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6950 - accuracy: 0.4640 - val_loss: 0.6942 - val_accuracy: 0.4560
# Epoch 5/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6935 - accuracy: 0.5120 - val_loss: 0.6969 - val_accuracy: 0.4600
# Epoch 6/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6936 - accuracy: 0.5133 - val_loss: 0.6982 - val_accuracy: 0.4600
# Epoch 7/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6934 - accuracy: 0.5133 - val_loss: 0.6952 - val_accuracy: 0.4600
# Epoch 8/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6935 - accuracy: 0.4947 - val_loss: 0.6942 - val_accuracy: 0.4600
# Epoch 9/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6935 - accuracy: 0.5133 - val_loss: 0.6977 - val_accuracy: 0.4600
# Epoch 10/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6939 - accuracy: 0.5133 - val_loss: 0.6947 - val_accuracy: 0.4600
# Epoch 11/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6927 - accuracy: 0.5133 - val_loss: 0.6946 - val_accuracy: 0.4600
# Epoch 12/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6928 - accuracy: 0.5013 - val_loss: 0.6966 - val_accuracy: 0.4600
# Epoch 13/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6930 - accuracy: 0.5133 - val_loss: 0.6953 - val_accuracy: 0.4600
# Epoch 14/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6925 - accuracy: 0.5133 - val_loss: 0.6959 - val_accuracy: 0.4600
# Epoch 15/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6919 - accuracy: 0.4907 - val_loss: 0.6945 - val_accuracy: 0.4280
# Epoch 16/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6912 - accuracy: 0.4427 - val_loss: 0.6973 - val_accuracy: 0.3840
# Epoch 17/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6912 - accuracy: 0.4747 - val_loss: 0.6948 - val_accuracy: 0.4600
# Epoch 18/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6894 - accuracy: 0.4733 - val_loss: 0.6969 - val_accuracy: 0.3640
# Epoch 19/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6881 - accuracy: 0.4667 - val_loss: 0.6956 - val_accuracy: 0.4400
# Epoch 20/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6872 - accuracy: 0.4720 - val_loss: 0.6935 - val_accuracy: 0.4800
# Epoch 21/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6839 - accuracy: 0.5173 - val_loss: 0.6911 - val_accuracy: 0.5200
# Epoch 22/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6823 - accuracy: 0.5173 - val_loss: 0.6922 - val_accuracy: 0.4600
# Epoch 23/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6785 - accuracy: 0.5373 - val_loss: 0.6863 - val_accuracy: 0.5280
# Epoch 24/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6754 - accuracy: 0.5680 - val_loss: 0.6829 - val_accuracy: 0.5520
# Epoch 25/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6721 - accuracy: 0.5400 - val_loss: 0.6833 - val_accuracy: 0.5040
# Epoch 26/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6660 - accuracy: 0.5720 - val_loss: 0.6737 - val_accuracy: 0.5640
# Epoch 27/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6614 - accuracy: 0.5653 - val_loss: 0.6696 - val_accuracy: 0.5360
# Epoch 28/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6555 - accuracy: 0.6347 - val_loss: 0.6622 - val_accuracy: 0.5480
# Epoch 29/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6475 - accuracy: 0.6173 - val_loss: 0.6553 - val_accuracy: 0.5800
# Epoch 30/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6412 - accuracy: 0.5880 - val_loss: 0.6485 - val_accuracy: 0.6080
# Epoch 31/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6309 - accuracy: 0.6867 - val_loss: 0.6369 - val_accuracy: 0.7080
# Epoch 32/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6236 - accuracy: 0.7120 - val_loss: 0.6290 - val_accuracy: 0.6920
# Epoch 33/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6117 - accuracy: 0.8093 - val_loss: 0.6141 - val_accuracy: 0.8240
# Epoch 34/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6014 - accuracy: 0.8373 - val_loss: 0.6047 - val_accuracy: 0.8080
# Epoch 35/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5910 - accuracy: 0.8147 - val_loss: 0.5933 - val_accuracy: 0.8400
# Epoch 36/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5794 - accuracy: 0.8707 - val_loss: 0.5790 - val_accuracy: 0.8840
# Epoch 37/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5654 - accuracy: 0.8880 - val_loss: 0.5645 - val_accuracy: 0.9080
# Epoch 38/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5531 - accuracy: 0.9000 - val_loss: 0.5504 - val_accuracy: 0.9200
# Epoch 39/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5391 - accuracy: 0.9187 - val_loss: 0.5363 - val_accuracy: 0.9280
# Epoch 40/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5259 - accuracy: 0.9080 - val_loss: 0.5223 - val_accuracy: 0.9320
# Epoch 41/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5126 - accuracy: 0.9147 - val_loss: 0.5075 - val_accuracy: 0.9400
# Epoch 42/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5005 - accuracy: 0.9307 - val_loss: 0.4931 - val_accuracy: 0.9320
# Epoch 43/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4876 - accuracy: 0.9307 - val_loss: 0.4813 - val_accuracy: 0.9320
# Epoch 44/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4752 - accuracy: 0.9307 - val_loss: 0.4666 - val_accuracy: 0.9440
# Epoch 45/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4637 - accuracy: 0.9347 - val_loss: 0.4547 - val_accuracy: 0.9400
# Epoch 46/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4518 - accuracy: 0.9347 - val_loss: 0.4409 - val_accuracy: 0.9480
# Epoch 47/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4405 - accuracy: 0.9347 - val_loss: 0.4320 - val_accuracy: 0.9400
# Epoch 48/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4301 - accuracy: 0.9413 - val_loss: 0.4191 - val_accuracy: 0.9440
# Epoch 49/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4224 - accuracy: 0.9333 - val_loss: 0.4085 - val_accuracy: 0.9480
# Epoch 50/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4107 - accuracy: 0.9453 - val_loss: 0.3997 - val_accuracy: 0.9400
# Epoch 51/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4013 - accuracy: 0.9400 - val_loss: 0.3888 - val_accuracy: 0.9480
# Epoch 52/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3923 - accuracy: 0.9347 - val_loss: 0.3817 - val_accuracy: 0.9400
# Epoch 53/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3833 - accuracy: 0.9360 - val_loss: 0.3697 - val_accuracy: 0.9480
# Epoch 54/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3753 - accuracy: 0.9413 - val_loss: 0.3618 - val_accuracy: 0.9480
# Epoch 55/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3667 - accuracy: 0.9373 - val_loss: 0.3541 - val_accuracy: 0.9480
# Epoch 56/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3597 - accuracy: 0.9387 - val_loss: 0.3454 - val_accuracy: 0.9480
# Epoch 57/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3511 - accuracy: 0.9427 - val_loss: 0.3390 - val_accuracy: 0.9400
# Epoch 58/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3443 - accuracy: 0.9427 - val_loss: 0.3298 - val_accuracy: 0.9480
# Epoch 59/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3370 - accuracy: 0.9400 - val_loss: 0.3224 - val_accuracy: 0.9520
# Epoch 60/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3305 - accuracy: 0.9440 - val_loss: 0.3149 - val_accuracy: 0.9520
# Epoch 61/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3233 - accuracy: 0.9453 - val_loss: 0.3103 - val_accuracy: 0.9480
# Epoch 62/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3166 - accuracy: 0.9467 - val_loss: 0.3033 - val_accuracy: 0.9480
# Epoch 63/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3096 - accuracy: 0.9493 - val_loss: 0.2967 - val_accuracy: 0.9480
# Epoch 64/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3037 - accuracy: 0.9453 - val_loss: 0.2897 - val_accuracy: 0.9480
# Epoch 65/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2987 - accuracy: 0.9493 - val_loss: 0.2850 - val_accuracy: 0.9480
# Epoch 66/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2899 - accuracy: 0.9520 - val_loss: 0.2775 - val_accuracy: 0.9480
# Epoch 67/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2844 - accuracy: 0.9493 - val_loss: 0.2717 - val_accuracy: 0.9480
# Epoch 68/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2784 - accuracy: 0.9533 - val_loss: 0.2679 - val_accuracy: 0.9480
# Epoch 69/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2735 - accuracy: 0.9573 - val_loss: 0.2606 - val_accuracy: 0.9480
# Epoch 70/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2678 - accuracy: 0.9547 - val_loss: 0.2560 - val_accuracy: 0.9560
# Epoch 71/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2609 - accuracy: 0.9600 - val_loss: 0.2511 - val_accuracy: 0.9480
# Epoch 72/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2556 - accuracy: 0.9640 - val_loss: 0.2455 - val_accuracy: 0.9520
# Epoch 73/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2500 - accuracy: 0.9613 - val_loss: 0.2410 - val_accuracy: 0.9560
# Epoch 74/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2450 - accuracy: 0.9680 - val_loss: 0.2371 - val_accuracy: 0.9520
# Epoch 75/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2398 - accuracy: 0.9680 - val_loss: 0.2308 - val_accuracy: 0.9560
# Epoch 76/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2348 - accuracy: 0.9667 - val_loss: 0.2262 - val_accuracy: 0.9560
# Epoch 77/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2295 - accuracy: 0.9707 - val_loss: 0.2221 - val_accuracy: 0.9600
# Epoch 78/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2245 - accuracy: 0.9720 - val_loss: 0.2173 - val_accuracy: 0.9600
# Epoch 79/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2197 - accuracy: 0.9733 - val_loss: 0.2128 - val_accuracy: 0.9640
# Epoch 80/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2154 - accuracy: 0.9707 - val_loss: 0.2094 - val_accuracy: 0.9720
# Epoch 81/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2110 - accuracy: 0.9760 - val_loss: 0.2054 - val_accuracy: 0.9760
# Epoch 82/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2065 - accuracy: 0.9827 - val_loss: 0.2013 - val_accuracy: 0.9840
# Epoch 83/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2023 - accuracy: 0.9813 - val_loss: 0.1975 - val_accuracy: 0.9840
# Epoch 84/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1981 - accuracy: 0.9853 - val_loss: 0.1942 - val_accuracy: 0.9840
# Epoch 85/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1937 - accuracy: 0.9853 - val_loss: 0.1900 - val_accuracy: 0.9840
# Epoch 86/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1900 - accuracy: 0.9880 - val_loss: 0.1861 - val_accuracy: 0.9880
# Epoch 87/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1867 - accuracy: 0.9880 - val_loss: 0.1826 - val_accuracy: 0.9920
# Epoch 88/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1819 - accuracy: 0.9920 - val_loss: 0.1799 - val_accuracy: 0.9960
# Epoch 89/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1787 - accuracy: 0.9960 - val_loss: 0.1763 - val_accuracy: 0.9960
# Epoch 90/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1749 - accuracy: 0.9973 - val_loss: 0.1731 - val_accuracy: 0.9960
# Epoch 91/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1715 - accuracy: 0.9973 - val_loss: 0.1705 - val_accuracy: 0.9960
# Epoch 92/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1677 - accuracy: 0.9973 - val_loss: 0.1672 - val_accuracy: 0.9960
# Epoch 93/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1648 - accuracy: 0.9960 - val_loss: 0.1637 - val_accuracy: 0.9960
# Epoch 94/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1616 - accuracy: 0.9973 - val_loss: 0.1612 - val_accuracy: 0.9960
# Epoch 95/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1585 - accuracy: 0.9973 - val_loss: 0.1580 - val_accuracy: 0.9960
# Epoch 96/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1552 - accuracy: 0.9973 - val_loss: 0.1553 - val_accuracy: 0.9960
# Epoch 97/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1524 - accuracy: 0.9987 - val_loss: 0.1529 - val_accuracy: 0.9960
# Epoch 98/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1498 - accuracy: 0.9973 - val_loss: 0.1504 - val_accuracy: 0.9960
# Epoch 99/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1466 - accuracy: 0.9987 - val_loss: 0.1476 - val_accuracy: 0.9960
# Epoch 100/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1439 - accuracy: 0.9987 - val_loss: 0.1452 - val_accuracy: 0.9960
# Epoch 101/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1411 - accuracy: 0.9987 - val_loss: 0.1428 - val_accuracy: 0.9960
# Epoch 102/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1385 - accuracy: 0.9987 - val_loss: 0.1404 - val_accuracy: 0.9960
# Epoch 103/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1364 - accuracy: 0.9987 - val_loss: 0.1382 - val_accuracy: 0.9960
# Epoch 104/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1337 - accuracy: 0.9987 - val_loss: 0.1355 - val_accuracy: 0.9960
# Epoch 105/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1310 - accuracy: 0.9987 - val_loss: 0.1340 - val_accuracy: 0.9960
# Epoch 106/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1288 - accuracy: 0.9987 - val_loss: 0.1318 - val_accuracy: 0.9960
# Epoch 107/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1263 - accuracy: 0.9987 - val_loss: 0.1294 - val_accuracy: 0.9960
# Epoch 108/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1244 - accuracy: 1.0000 - val_loss: 0.1275 - val_accuracy: 0.9960
# Epoch 109/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1226 - accuracy: 0.9987 - val_loss: 0.1247 - val_accuracy: 0.9960
# Epoch 110/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1202 - accuracy: 1.0000 - val_loss: 0.1234 - val_accuracy: 0.9960
# Epoch 111/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1178 - accuracy: 1.0000 - val_loss: 0.1213 - val_accuracy: 0.9960
# Epoch 112/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1159 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.9960
# Epoch 113/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1137 - accuracy: 1.0000 - val_loss: 0.1180 - val_accuracy: 0.9960
# Epoch 114/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1119 - accuracy: 0.9987 - val_loss: 0.1163 - val_accuracy: 0.9960
# Epoch 115/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1100 - accuracy: 0.9987 - val_loss: 0.1144 - val_accuracy: 0.9960
# Epoch 116/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1087 - accuracy: 0.9987 - val_loss: 0.1121 - val_accuracy: 0.9960
# Epoch 117/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1066 - accuracy: 1.0000 - val_loss: 0.1110 - val_accuracy: 0.9960
# Epoch 118/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1047 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9960
# Epoch 119/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1031 - accuracy: 0.9987 - val_loss: 0.1078 - val_accuracy: 0.9960
# Epoch 120/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1016 - accuracy: 1.0000 - val_loss: 0.1069 - val_accuracy: 0.9960
# Epoch 121/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1001 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9960
# Epoch 122/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0983 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9960
# Epoch 123/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9987 - val_loss: 0.1018 - val_accuracy: 0.9960
# Epoch 124/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 0.9960
# Epoch 125/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0939 - accuracy: 1.0000 - val_loss: 0.0994 - val_accuracy: 0.9960
# Epoch 126/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0923 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9960
# Epoch 127/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0909 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9960
# Epoch 128/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9960
# Epoch 129/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0882 - accuracy: 1.0000 - val_loss: 0.0941 - val_accuracy: 0.9960
# Epoch 130/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0872 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9960
# Epoch 131/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0859 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9960
# Epoch 132/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0844 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9960
# Epoch 133/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0832 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 134/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0820 - accuracy: 1.0000 - val_loss: 0.0879 - val_accuracy: 0.9960
# Epoch 135/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0811 - accuracy: 0.9987 - val_loss: 0.0866 - val_accuracy: 0.9960
# Epoch 136/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0797 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9960
# Epoch 137/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0787 - accuracy: 1.0000 - val_loss: 0.0846 - val_accuracy: 0.9960
# Epoch 138/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0776 - accuracy: 1.0000 - val_loss: 0.0839 - val_accuracy: 0.9960
# Epoch 139/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 1.0000 - val_loss: 0.0830 - val_accuracy: 0.9960
# Epoch 140/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9987 - val_loss: 0.0821 - val_accuracy: 0.9960
# Epoch 141/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0747 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 1.0000
# Epoch 142/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0735 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 0.9960
# Epoch 143/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0725 - accuracy: 1.0000 - val_loss: 0.0793 - val_accuracy: 0.9960
# Epoch 144/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0716 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9960
# Epoch 145/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0707 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9960
# Epoch 146/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0700 - accuracy: 1.0000 - val_loss: 0.0762 - val_accuracy: 0.9960
# Epoch 147/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 1.0000
# Epoch 148/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0680 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9960
# Epoch 149/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0674 - accuracy: 0.9987 - val_loss: 0.0741 - val_accuracy: 0.9960
# Epoch 150/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9960
# Epoch 151/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 1.0000 - val_loss: 0.0726 - val_accuracy: 0.9960
# Epoch 152/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.0711 - val_accuracy: 0.9960
# Epoch 153/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0641 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9960
# Epoch 154/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9960
# Epoch 155/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0625 - accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 1.0000
# Epoch 156/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 1.0000 - val_loss: 0.0684 - val_accuracy: 1.0000
# Epoch 157/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0614 - accuracy: 1.0000 - val_loss: 0.0678 - val_accuracy: 0.9960
# Epoch 158/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 1.0000
# Epoch 159/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0597 - accuracy: 1.0000 - val_loss: 0.0671 - val_accuracy: 0.9960
# Epoch 160/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0590 - accuracy: 0.9987 - val_loss: 0.0655 - val_accuracy: 1.0000
# Epoch 161/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0584 - accuracy: 1.0000 - val_loss: 0.0650 - val_accuracy: 1.0000
# Epoch 162/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9960
# Epoch 163/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9960
# Epoch 164/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0561 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 1.0000
# Epoch 165/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9960
# Epoch 166/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 1.0000
# Epoch 167/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 1.0000
# Epoch 168/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 1.0000
# Epoch 169/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 170/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.0597 - val_accuracy: 0.9960
# Epoch 171/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.0593 - val_accuracy: 0.9960
# Epoch 172/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0516 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 1.0000
# Epoch 173/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.0587 - val_accuracy: 0.9960
# Epoch 174/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 1.0000
# Epoch 175/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 0.0576 - val_accuracy: 0.9960
# Epoch 176/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0493 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 1.0000
# Epoch 177/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.0561 - val_accuracy: 0.9960
# Epoch 178/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 1.0000 - val_loss: 0.0558 - val_accuracy: 1.0000
# Epoch 179/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0481 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 1.0000
# Epoch 180/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0474 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 181/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 1.0000
# Epoch 182/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 1.0000 - val_loss: 0.0540 - val_accuracy: 0.9960
# Epoch 183/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 1.0000 - val_loss: 0.0527 - val_accuracy: 1.0000
# Epoch 184/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0454 - accuracy: 1.0000 - val_loss: 0.0537 - val_accuracy: 0.9960
# Epoch 185/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0451 - accuracy: 1.0000 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 186/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 187/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 1.0000
# Epoch 188/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.0515 - val_accuracy: 0.9960
# Epoch 189/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.0512 - val_accuracy: 0.9960
# Epoch 190/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0432 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 191/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.0503 - val_accuracy: 0.9960
# Epoch 192/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 193/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 1.0000
# Epoch 194/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 1.0000 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 195/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0410 - accuracy: 1.0000 - val_loss: 0.0481 - val_accuracy: 0.9960
# Epoch 196/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0405 - accuracy: 1.0000 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 197/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 198/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0400 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 199/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0396 - accuracy: 1.0000 - val_loss: 0.0473 - val_accuracy: 0.9960
# Epoch 200/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0391 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 1.0000

# %% [markdown]
# If we train this enough, we can get it down to almost perfect.
#
# **Note:** If you call fit() again, it will continue from the already trained weights. This is a way to experiment with the number of epochs run.

# %%
plot_probabilities(ann1, X_circles, y_circles, colors, post_process=np.round)
# Out:
# 1250/1250 [==============================] - 2s 2ms/step

# %% [markdown]
# With a network as simple as this, it's easy to get a feel for how the network works by inspecting the output of the hidden layer.

# %%
early_layers = ann1.layers[:-1]

# %% [markdown]
# This is an array containing all the layers but the top one. (That is, the hidden layer and the implicit input layer.)

# %%
hidden = tf.keras.Sequential(early_layers)

# %% [markdown]
# We create a new neural network with the remaining layers. These layers retain their weights and biases, so we can use this to examine how the network works.
#
# It could also be used as a _pre-trained_ network to be used as the basis for another ANN. This is of course more relevant with more complex networks.

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 15))

plot_probabilities(hidden, X_circles, y_circles, colors, ax=axes[0][0])
plot_probabilities(hidden, X_circles, y_circles, colors, dim=1, ax=axes[0][1])
plot_probabilities(hidden, X_circles, y_circles, colors, dim=2, ax=axes[1][0])
plot_probabilities(hidden, X_circles, y_circles, colors, dim=3, ax=axes[1][1])
# Out:
# 1250/1250 [==============================] - 2s 2ms/step
# 1250/1250 [==============================] - 2s 2ms/step
# 1250/1250 [==============================] - 2s 2ms/step
# 1250/1250 [==============================] - 2s 2ms/step

# %% [markdown]
# ### Moons
#
# The moons are more complex, so let's try adding another layer (we could also have tried more neurons in the hidden layer).

# %%
tf.random.set_seed(504)
ann2 = tf.keras.Sequential([
  layers.Dense(4, input_dim=2, activation="sigmoid"),
  layers.Dense(4, activation="sigmoid"),
  layers.Dense(1, activation="sigmoid")])

ann2.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=.01), metrics=['accuracy'])

# %% [markdown]
# 200 epochs is a lot for these simple problems. Either they hit a plateau or they converge before that. Instead of fine tuning that each time, let's add a callback.
#
# The *early stopping* callback is called after each epoch and evaluates if the optimizer is making much progress (by default by looking at the validation loss). In the example, the fitting stops if no progress has been made for the last 20 epochs.

# %%
es = tf.keras.callbacks.EarlyStopping(patience=20, restore_best_weights=True)

# %% [markdown]
# It doesn't go well.

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_moons, y_moons, random_state=504)

history = ann2.fit(X_train, y_train, epochs=200, validation_data=(X_valid, y_valid), callbacks=[es])
# Out:
# Epoch 1/200
# 24/24 [==============================] - 1s 15ms/step - loss: 0.6940 - accuracy: 0.5000 - val_loss: 0.6865 - val_accuracy: 0.4600
# Epoch 2/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6672 - accuracy: 0.7560 - val_loss: 0.6486 - val_accuracy: 0.8160
# Epoch 3/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6210 - accuracy: 0.8347 - val_loss: 0.5854 - val_accuracy: 0.8360
# Epoch 4/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5460 - accuracy: 0.8293 - val_loss: 0.4988 - val_accuracy: 0.8360
# Epoch 5/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4582 - accuracy: 0.8347 - val_loss: 0.4280 - val_accuracy: 0.8400
# Epoch 6/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3922 - accuracy: 0.8560 - val_loss: 0.3852 - val_accuracy: 0.8440
# Epoch 7/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3516 - accuracy: 0.8600 - val_loss: 0.3586 - val_accuracy: 0.8560
# Epoch 8/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3282 - accuracy: 0.8653 - val_loss: 0.3452 - val_accuracy: 0.8560
# Epoch 9/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3155 - accuracy: 0.8720 - val_loss: 0.3377 - val_accuracy: 0.8560
# Epoch 10/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3087 - accuracy: 0.8667 - val_loss: 0.3342 - val_accuracy: 0.8560
# Epoch 11/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3042 - accuracy: 0.8880 - val_loss: 0.3326 - val_accuracy: 0.8560
# Epoch 12/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2999 - accuracy: 0.8720 - val_loss: 0.3317 - val_accuracy: 0.8640
# Epoch 13/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2975 - accuracy: 0.8827 - val_loss: 0.3323 - val_accuracy: 0.8640
# Epoch 14/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2958 - accuracy: 0.8813 - val_loss: 0.3311 - val_accuracy: 0.8640
# Epoch 15/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2945 - accuracy: 0.8773 - val_loss: 0.3312 - val_accuracy: 0.8640
# Epoch 16/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2933 - accuracy: 0.8813 - val_loss: 0.3306 - val_accuracy: 0.8640
# Epoch 17/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2922 - accuracy: 0.8827 - val_loss: 0.3301 - val_accuracy: 0.8640
# Epoch 18/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.2911 - accuracy: 0.8800 - val_loss: 0.3298 - val_accuracy: 0.8600
# Epoch 19/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2907 - accuracy: 0.8867 - val_loss: 0.3303 - val_accuracy: 0.8640
# Epoch 20/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2934 - accuracy: 0.8720 - val_loss: 0.3312 - val_accuracy: 0.8640
# Epoch 21/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2895 - accuracy: 0.8893 - val_loss: 0.3299 - val_accuracy: 0.8600
# Epoch 22/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2894 - accuracy: 0.8827 - val_loss: 0.3299 - val_accuracy: 0.8640
# Epoch 23/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2885 - accuracy: 0.8827 - val_loss: 0.3292 - val_accuracy: 0.8600
# Epoch 24/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2885 - accuracy: 0.8813 - val_loss: 0.3285 - val_accuracy: 0.8600
# Epoch 25/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2886 - accuracy: 0.8787 - val_loss: 0.3286 - val_accuracy: 0.8600
# Epoch 26/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2880 - accuracy: 0.8840 - val_loss: 0.3281 - val_accuracy: 0.8600
# Epoch 27/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2867 - accuracy: 0.8813 - val_loss: 0.3282 - val_accuracy: 0.8680
# Epoch 28/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2857 - accuracy: 0.8880 - val_loss: 0.3278 - val_accuracy: 0.8600
# Epoch 29/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2864 - accuracy: 0.8773 - val_loss: 0.3276 - val_accuracy: 0.8600
# Epoch 30/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2867 - accuracy: 0.8787 - val_loss: 0.3277 - val_accuracy: 0.8680
# Epoch 31/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2871 - accuracy: 0.8800 - val_loss: 0.3268 - val_accuracy: 0.8640
# Epoch 32/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2861 - accuracy: 0.8800 - val_loss: 0.3272 - val_accuracy: 0.8600
# Epoch 33/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2867 - accuracy: 0.8760 - val_loss: 0.3265 - val_accuracy: 0.8680
# Epoch 34/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2835 - accuracy: 0.8827 - val_loss: 0.3266 - val_accuracy: 0.8600
# Epoch 35/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2841 - accuracy: 0.8853 - val_loss: 0.3267 - val_accuracy: 0.8600
# Epoch 36/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2858 - accuracy: 0.8813 - val_loss: 0.3262 - val_accuracy: 0.8640
# Epoch 37/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2873 - accuracy: 0.8840 - val_loss: 0.3274 - val_accuracy: 0.8640
# Epoch 38/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2858 - accuracy: 0.8760 - val_loss: 0.3269 - val_accuracy: 0.8680
# Epoch 39/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2836 - accuracy: 0.8827 - val_loss: 0.3265 - val_accuracy: 0.8640
# Epoch 40/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2860 - accuracy: 0.8760 - val_loss: 0.3258 - val_accuracy: 0.8640
# Epoch 41/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2821 - accuracy: 0.8840 - val_loss: 0.3253 - val_accuracy: 0.8600
# Epoch 42/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2817 - accuracy: 0.8800 - val_loss: 0.3254 - val_accuracy: 0.8600
# Epoch 43/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2820 - accuracy: 0.8867 - val_loss: 0.3251 - val_accuracy: 0.8600
# Epoch 44/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2858 - accuracy: 0.8813 - val_loss: 0.3286 - val_accuracy: 0.8680
# Epoch 45/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2855 - accuracy: 0.8773 - val_loss: 0.3245 - val_accuracy: 0.8640
# Epoch 46/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2849 - accuracy: 0.8787 - val_loss: 0.3256 - val_accuracy: 0.8680
# Epoch 47/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2810 - accuracy: 0.8813 - val_loss: 0.3246 - val_accuracy: 0.8600
# Epoch 48/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2826 - accuracy: 0.8840 - val_loss: 0.3247 - val_accuracy: 0.8640
# Epoch 49/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2832 - accuracy: 0.8800 - val_loss: 0.3259 - val_accuracy: 0.8640
# Epoch 50/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.8760 - val_loss: 0.3252 - val_accuracy: 0.8680
# Epoch 51/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2868 - accuracy: 0.8720 - val_loss: 0.3271 - val_accuracy: 0.8680
# Epoch 52/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2812 - accuracy: 0.8800 - val_loss: 0.3242 - val_accuracy: 0.8600
# Epoch 53/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2804 - accuracy: 0.8853 - val_loss: 0.3240 - val_accuracy: 0.8600
# Epoch 54/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2798 - accuracy: 0.8893 - val_loss: 0.3228 - val_accuracy: 0.8600
# Epoch 55/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2809 - accuracy: 0.8840 - val_loss: 0.3230 - val_accuracy: 0.8640
# Epoch 56/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2809 - accuracy: 0.8827 - val_loss: 0.3238 - val_accuracy: 0.8600
# Epoch 57/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2804 - accuracy: 0.8813 - val_loss: 0.3235 - val_accuracy: 0.8600
# Epoch 58/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2808 - accuracy: 0.8840 - val_loss: 0.3231 - val_accuracy: 0.8680
# Epoch 59/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2804 - accuracy: 0.8827 - val_loss: 0.3230 - val_accuracy: 0.8680
# Epoch 60/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2805 - accuracy: 0.8827 - val_loss: 0.3229 - val_accuracy: 0.8680
# Epoch 61/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2791 - accuracy: 0.8800 - val_loss: 0.3235 - val_accuracy: 0.8600
# Epoch 62/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2834 - accuracy: 0.8840 - val_loss: 0.3234 - val_accuracy: 0.8680
# Epoch 63/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2815 - accuracy: 0.8813 - val_loss: 0.3228 - val_accuracy: 0.8600
# Epoch 64/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2805 - accuracy: 0.8773 - val_loss: 0.3239 - val_accuracy: 0.8600
# Epoch 65/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2795 - accuracy: 0.8840 - val_loss: 0.3233 - val_accuracy: 0.8600
# Epoch 66/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2787 - accuracy: 0.8800 - val_loss: 0.3220 - val_accuracy: 0.8640
# Epoch 67/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2785 - accuracy: 0.8853 - val_loss: 0.3227 - val_accuracy: 0.8640
# Epoch 68/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2782 - accuracy: 0.8800 - val_loss: 0.3229 - val_accuracy: 0.8600
# Epoch 69/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2824 - accuracy: 0.8733 - val_loss: 0.3218 - val_accuracy: 0.8640
# Epoch 70/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2825 - accuracy: 0.8840 - val_loss: 0.3228 - val_accuracy: 0.8600
# Epoch 71/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.8840 - val_loss: 0.3234 - val_accuracy: 0.8600
# Epoch 72/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2784 - accuracy: 0.8813 - val_loss: 0.3225 - val_accuracy: 0.8640
# Epoch 73/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2791 - accuracy: 0.8813 - val_loss: 0.3257 - val_accuracy: 0.8680
# Epoch 74/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2791 - accuracy: 0.8840 - val_loss: 0.3225 - val_accuracy: 0.8600
# Epoch 75/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2780 - accuracy: 0.8800 - val_loss: 0.3219 - val_accuracy: 0.8640
# Epoch 76/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2812 - accuracy: 0.8787 - val_loss: 0.3218 - val_accuracy: 0.8680
# Epoch 77/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2829 - accuracy: 0.8787 - val_loss: 0.3229 - val_accuracy: 0.8640
# Epoch 78/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2787 - accuracy: 0.8800 - val_loss: 0.3215 - val_accuracy: 0.8640
# Epoch 79/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2796 - accuracy: 0.8867 - val_loss: 0.3216 - val_accuracy: 0.8640
# Epoch 80/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2781 - accuracy: 0.8827 - val_loss: 0.3222 - val_accuracy: 0.8600
# Epoch 81/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2802 - accuracy: 0.8773 - val_loss: 0.3222 - val_accuracy: 0.8600
# Epoch 82/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2779 - accuracy: 0.8787 - val_loss: 0.3209 - val_accuracy: 0.8680
# Epoch 83/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2799 - accuracy: 0.8773 - val_loss: 0.3214 - val_accuracy: 0.8640
# Epoch 84/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2774 - accuracy: 0.8840 - val_loss: 0.3217 - val_accuracy: 0.8600
# Epoch 85/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2789 - accuracy: 0.8813 - val_loss: 0.3238 - val_accuracy: 0.8640
# Epoch 86/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2770 - accuracy: 0.8787 - val_loss: 0.3220 - val_accuracy: 0.8680
# Epoch 87/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2804 - accuracy: 0.8867 - val_loss: 0.3219 - val_accuracy: 0.8600
# Epoch 88/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2777 - accuracy: 0.8840 - val_loss: 0.3244 - val_accuracy: 0.8680
# Epoch 89/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2830 - accuracy: 0.8787 - val_loss: 0.3230 - val_accuracy: 0.8680
# Epoch 90/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2821 - accuracy: 0.8813 - val_loss: 0.3246 - val_accuracy: 0.8680
# Epoch 91/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2792 - accuracy: 0.8773 - val_loss: 0.3213 - val_accuracy: 0.8600
# Epoch 92/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2777 - accuracy: 0.8800 - val_loss: 0.3204 - val_accuracy: 0.8640
# Epoch 93/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2775 - accuracy: 0.8840 - val_loss: 0.3230 - val_accuracy: 0.8640
# Epoch 94/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2801 - accuracy: 0.8720 - val_loss: 0.3218 - val_accuracy: 0.8680
# Epoch 95/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2818 - accuracy: 0.8827 - val_loss: 0.3229 - val_accuracy: 0.8600
# Epoch 96/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2764 - accuracy: 0.8840 - val_loss: 0.3209 - val_accuracy: 0.8640
# Epoch 97/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2764 - accuracy: 0.8827 - val_loss: 0.3221 - val_accuracy: 0.8600
# Epoch 98/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2779 - accuracy: 0.8787 - val_loss: 0.3212 - val_accuracy: 0.8680
# Epoch 99/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2813 - accuracy: 0.8800 - val_loss: 0.3205 - val_accuracy: 0.8680
# Epoch 100/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2788 - accuracy: 0.8773 - val_loss: 0.3204 - val_accuracy: 0.8680
# Epoch 101/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2776 - accuracy: 0.8853 - val_loss: 0.3211 - val_accuracy: 0.8640
# Epoch 102/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2800 - accuracy: 0.8800 - val_loss: 0.3244 - val_accuracy: 0.8680
# Epoch 103/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2831 - accuracy: 0.8787 - val_loss: 0.3221 - val_accuracy: 0.8640
# Epoch 104/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2778 - accuracy: 0.8813 - val_loss: 0.3210 - val_accuracy: 0.8600
# Epoch 105/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2767 - accuracy: 0.8893 - val_loss: 0.3197 - val_accuracy: 0.8600
# Epoch 106/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.8747 - val_loss: 0.3181 - val_accuracy: 0.8640
# Epoch 107/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2792 - accuracy: 0.8773 - val_loss: 0.3219 - val_accuracy: 0.8640
# Epoch 108/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2784 - accuracy: 0.8773 - val_loss: 0.3207 - val_accuracy: 0.8600
# Epoch 109/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2787 - accuracy: 0.8800 - val_loss: 0.3198 - val_accuracy: 0.8680
# Epoch 110/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2782 - accuracy: 0.8827 - val_loss: 0.3201 - val_accuracy: 0.8640
# Epoch 111/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2784 - accuracy: 0.8813 - val_loss: 0.3230 - val_accuracy: 0.8640
# Epoch 112/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2771 - accuracy: 0.8747 - val_loss: 0.3198 - val_accuracy: 0.8680
# Epoch 113/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2783 - accuracy: 0.8813 - val_loss: 0.3208 - val_accuracy: 0.8680
# Epoch 114/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2778 - accuracy: 0.8733 - val_loss: 0.3205 - val_accuracy: 0.8600
# Epoch 115/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2759 - accuracy: 0.8800 - val_loss: 0.3210 - val_accuracy: 0.8600
# Epoch 116/200
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2796 - accuracy: 0.8773 - val_loss: 0.3203 - val_accuracy: 0.8640
# Epoch 117/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 0.8827 - val_loss: 0.3204 - val_accuracy: 0.8600
# Epoch 118/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2760 - accuracy: 0.8840 - val_loss: 0.3199 - val_accuracy: 0.8600
# Epoch 119/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2753 - accuracy: 0.8867 - val_loss: 0.3195 - val_accuracy: 0.8600
# Epoch 120/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2767 - accuracy: 0.8760 - val_loss: 0.3192 - val_accuracy: 0.8680
# Epoch 121/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2751 - accuracy: 0.8813 - val_loss: 0.3218 - val_accuracy: 0.8600
# Epoch 122/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2757 - accuracy: 0.8827 - val_loss: 0.3196 - val_accuracy: 0.8600
# Epoch 123/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2763 - accuracy: 0.8840 - val_loss: 0.3196 - val_accuracy: 0.8640
# Epoch 124/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2752 - accuracy: 0.8840 - val_loss: 0.3198 - val_accuracy: 0.8600
# Epoch 125/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2754 - accuracy: 0.8800 - val_loss: 0.3191 - val_accuracy: 0.8640
# Epoch 126/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2752 - accuracy: 0.8853 - val_loss: 0.3197 - val_accuracy: 0.8600

# %%
plt.figure()
plt.title("Learning curves")
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'valid')
plt.legend()
plt.show()

# %%
plot_probabilities(ann2, X_moons, y_moons, colors, post_process=np.round)
# Out:
# 1172/1172 [==============================] - 2s 2ms/step

# %% [markdown]
# The sigmoid activation function has a very small window of operations before it causes vanishing gradients. For this reason, it is not used much except when you specifically want a probability.
#
# We'll replace it with ReLU (tanh works, too).

# %%
ann2 = tf.keras.Sequential([
  layers.Dense(4, input_dim=2, activation="relu"),
  layers.Dense(4, activation="relu"),
  layers.Dense(1, activation="sigmoid")])

ann2.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=.005), metrics=['accuracy'])
history = ann2.fit(X_train, y_train, epochs=200, validation_data=(X_valid, y_valid), verbose = 0, callbacks=[es])

# %%
plt.figure()
plt.title("Learning curves")
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'valid')
plt.legend()
plt.show()

# %%
plot_probabilities(ann2, X_moons, y_moons, colors, post_process=np.round)
# Out:
# 1172/1172 [==============================] - 2s 2ms/step

# %% [markdown]
# Alternatively, we can _normalize_ the data between layers. The batch normalization layer scales the data to a (learned) mean and standard deviation. This helps keep the values in the active region. It is commonly used with sigmoid and tanh activation functions.

# %%
ann2 = tf.keras.Sequential([
  layers.Dense(4, input_dim=2, activation="sigmoid"),
  layers.BatchNormalization(),
  layers.Dense(4, activation="sigmoid"),
  layers.BatchNormalization(),
  layers.Dense(1, activation="sigmoid")])

ann2.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=.002), metrics=['accuracy'])

# %%
history=ann2.fit(X_train, y_train, epochs=200, validation_data=(X_valid, y_valid), callbacks=[es])
# Out:
# Epoch 1/200
# 24/24 [==============================] - 3s 21ms/step - loss: 0.4082 - accuracy: 0.7907 - val_loss: 0.7524 - val_accuracy: 0.4600
# Epoch 2/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.3385 - accuracy: 0.8600 - val_loss: 0.7534 - val_accuracy: 0.4600
# Epoch 3/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.3100 - accuracy: 0.8693 - val_loss: 0.7510 - val_accuracy: 0.4600
# Epoch 4/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2965 - accuracy: 0.8680 - val_loss: 0.7232 - val_accuracy: 0.4600
# Epoch 5/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2966 - accuracy: 0.8773 - val_loss: 0.7010 - val_accuracy: 0.4600
# Epoch 6/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2846 - accuracy: 0.8720 - val_loss: 0.6809 - val_accuracy: 0.4600
# Epoch 7/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2867 - accuracy: 0.8720 - val_loss: 0.6395 - val_accuracy: 0.4640
# Epoch 8/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2880 - accuracy: 0.8787 - val_loss: 0.5906 - val_accuracy: 0.6040
# Epoch 9/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2799 - accuracy: 0.8733 - val_loss: 0.5513 - val_accuracy: 0.7080
# Epoch 10/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2984 - accuracy: 0.8720 - val_loss: 0.5225 - val_accuracy: 0.7480
# Epoch 11/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2718 - accuracy: 0.8813 - val_loss: 0.4731 - val_accuracy: 0.8160
# Epoch 12/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2776 - accuracy: 0.8840 - val_loss: 0.4302 - val_accuracy: 0.8440
# Epoch 13/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2857 - accuracy: 0.8787 - val_loss: 0.4008 - val_accuracy: 0.8560
# Epoch 14/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2782 - accuracy: 0.8867 - val_loss: 0.3907 - val_accuracy: 0.8560
# Epoch 15/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2806 - accuracy: 0.8733 - val_loss: 0.3744 - val_accuracy: 0.8640
# Epoch 16/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2613 - accuracy: 0.8800 - val_loss: 0.3554 - val_accuracy: 0.8640
# Epoch 17/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2752 - accuracy: 0.8760 - val_loss: 0.3525 - val_accuracy: 0.8600
# Epoch 18/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2580 - accuracy: 0.8787 - val_loss: 0.3355 - val_accuracy: 0.8600
# Epoch 19/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2733 - accuracy: 0.8813 - val_loss: 0.3701 - val_accuracy: 0.8560
# Epoch 20/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2616 - accuracy: 0.8800 - val_loss: 0.3754 - val_accuracy: 0.8480
# Epoch 21/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2473 - accuracy: 0.8933 - val_loss: 0.4000 - val_accuracy: 0.8360
# Epoch 22/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2473 - accuracy: 0.8893 - val_loss: 0.4593 - val_accuracy: 0.7840
# Epoch 23/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2220 - accuracy: 0.8987 - val_loss: 0.4313 - val_accuracy: 0.8240
# Epoch 24/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2012 - accuracy: 0.9147 - val_loss: 0.4021 - val_accuracy: 0.8240
# Epoch 25/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.2169 - accuracy: 0.9160 - val_loss: 0.4094 - val_accuracy: 0.8200
# Epoch 26/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1896 - accuracy: 0.9240 - val_loss: 0.4021 - val_accuracy: 0.8320
# Epoch 27/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1913 - accuracy: 0.9307 - val_loss: 0.3682 - val_accuracy: 0.8680
# Epoch 28/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1880 - accuracy: 0.9240 - val_loss: 0.4584 - val_accuracy: 0.7720
# Epoch 29/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1701 - accuracy: 0.9360 - val_loss: 0.3875 - val_accuracy: 0.8440
# Epoch 30/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1682 - accuracy: 0.9360 - val_loss: 0.2468 - val_accuracy: 0.9080
# Epoch 31/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1613 - accuracy: 0.9400 - val_loss: 0.2129 - val_accuracy: 0.9240
# Epoch 32/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1730 - accuracy: 0.9347 - val_loss: 0.2138 - val_accuracy: 0.9160
# Epoch 33/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1398 - accuracy: 0.9453 - val_loss: 0.2344 - val_accuracy: 0.9240
# Epoch 34/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1411 - accuracy: 0.9440 - val_loss: 0.2838 - val_accuracy: 0.8760
# Epoch 35/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1399 - accuracy: 0.9453 - val_loss: 0.3101 - val_accuracy: 0.8560
# Epoch 36/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1502 - accuracy: 0.9480 - val_loss: 0.2283 - val_accuracy: 0.9160
# Epoch 37/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1377 - accuracy: 0.9453 - val_loss: 0.1510 - val_accuracy: 0.9360
# Epoch 38/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1469 - accuracy: 0.9453 - val_loss: 0.1399 - val_accuracy: 0.9560
# Epoch 39/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1465 - accuracy: 0.9480 - val_loss: 0.1669 - val_accuracy: 0.9360
# Epoch 40/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1222 - accuracy: 0.9507 - val_loss: 0.1282 - val_accuracy: 0.9440
# Epoch 41/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1459 - accuracy: 0.9453 - val_loss: 0.1239 - val_accuracy: 0.9400
# Epoch 42/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1389 - accuracy: 0.9507 - val_loss: 0.1279 - val_accuracy: 0.9600
# Epoch 43/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1404 - accuracy: 0.9493 - val_loss: 0.1212 - val_accuracy: 0.9560
# Epoch 44/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1081 - accuracy: 0.9547 - val_loss: 0.1229 - val_accuracy: 0.9560
# Epoch 45/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1407 - accuracy: 0.9467 - val_loss: 0.1244 - val_accuracy: 0.9480
# Epoch 46/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1304 - accuracy: 0.9533 - val_loss: 0.1542 - val_accuracy: 0.9440
# Epoch 47/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1356 - accuracy: 0.9480 - val_loss: 0.1080 - val_accuracy: 0.9600
# Epoch 48/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1302 - accuracy: 0.9573 - val_loss: 0.1056 - val_accuracy: 0.9560
# Epoch 49/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1425 - accuracy: 0.9467 - val_loss: 0.2053 - val_accuracy: 0.9200
# Epoch 50/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1188 - accuracy: 0.9573 - val_loss: 0.1064 - val_accuracy: 0.9600
# Epoch 51/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1218 - accuracy: 0.9533 - val_loss: 0.1141 - val_accuracy: 0.9600
# Epoch 52/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1192 - accuracy: 0.9493 - val_loss: 0.0993 - val_accuracy: 0.9600
# Epoch 53/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1193 - accuracy: 0.9533 - val_loss: 0.1028 - val_accuracy: 0.9560
# Epoch 54/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1135 - accuracy: 0.9533 - val_loss: 0.1096 - val_accuracy: 0.9560
# Epoch 55/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1168 - accuracy: 0.9613 - val_loss: 0.1098 - val_accuracy: 0.9600
# Epoch 56/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1209 - accuracy: 0.9573 - val_loss: 0.1218 - val_accuracy: 0.9600
# Epoch 57/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1000 - accuracy: 0.9693 - val_loss: 0.1001 - val_accuracy: 0.9560
# Epoch 58/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1061 - accuracy: 0.9573 - val_loss: 0.0998 - val_accuracy: 0.9560
# Epoch 59/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1180 - accuracy: 0.9547 - val_loss: 0.1014 - val_accuracy: 0.9560
# Epoch 60/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1296 - accuracy: 0.9507 - val_loss: 0.1255 - val_accuracy: 0.9560
# Epoch 61/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1254 - accuracy: 0.9547 - val_loss: 0.1196 - val_accuracy: 0.9520
# Epoch 62/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1151 - accuracy: 0.9520 - val_loss: 0.1707 - val_accuracy: 0.9440
# Epoch 63/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1365 - accuracy: 0.9387 - val_loss: 0.0985 - val_accuracy: 0.9600
# Epoch 64/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1220 - accuracy: 0.9520 - val_loss: 0.1662 - val_accuracy: 0.9320
# Epoch 65/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1179 - accuracy: 0.9520 - val_loss: 0.0924 - val_accuracy: 0.9720
# Epoch 66/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1227 - accuracy: 0.9520 - val_loss: 0.1071 - val_accuracy: 0.9600
# Epoch 67/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1017 - accuracy: 0.9560 - val_loss: 0.1325 - val_accuracy: 0.9480
# Epoch 68/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0949 - accuracy: 0.9573 - val_loss: 0.1140 - val_accuracy: 0.9560
# Epoch 69/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1235 - accuracy: 0.9520 - val_loss: 0.0965 - val_accuracy: 0.9640
# Epoch 70/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1196 - accuracy: 0.9520 - val_loss: 0.1168 - val_accuracy: 0.9640
# Epoch 71/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1038 - accuracy: 0.9533 - val_loss: 0.0940 - val_accuracy: 0.9600
# Epoch 72/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1139 - accuracy: 0.9613 - val_loss: 0.1068 - val_accuracy: 0.9520
# Epoch 73/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1011 - accuracy: 0.9600 - val_loss: 0.0983 - val_accuracy: 0.9680
# Epoch 74/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1391 - accuracy: 0.9467 - val_loss: 0.0916 - val_accuracy: 0.9640
# Epoch 75/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1070 - accuracy: 0.9573 - val_loss: 0.1023 - val_accuracy: 0.9520
# Epoch 76/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1156 - accuracy: 0.9533 - val_loss: 0.0950 - val_accuracy: 0.9600
# Epoch 77/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0943 - accuracy: 0.9667 - val_loss: 0.0918 - val_accuracy: 0.9680
# Epoch 78/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9533 - val_loss: 0.1051 - val_accuracy: 0.9560
# Epoch 79/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1168 - accuracy: 0.9600 - val_loss: 0.1054 - val_accuracy: 0.9640
# Epoch 80/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1028 - accuracy: 0.9533 - val_loss: 0.0907 - val_accuracy: 0.9640
# Epoch 81/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1181 - accuracy: 0.9600 - val_loss: 0.0934 - val_accuracy: 0.9600
# Epoch 82/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0985 - accuracy: 0.9627 - val_loss: 0.0982 - val_accuracy: 0.9600
# Epoch 83/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1373 - accuracy: 0.9533 - val_loss: 0.0925 - val_accuracy: 0.9640
# Epoch 84/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1150 - accuracy: 0.9547 - val_loss: 0.0929 - val_accuracy: 0.9600
# Epoch 85/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1083 - accuracy: 0.9640 - val_loss: 0.0960 - val_accuracy: 0.9680
# Epoch 86/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1124 - accuracy: 0.9547 - val_loss: 0.0904 - val_accuracy: 0.9640
# Epoch 87/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1005 - accuracy: 0.9573 - val_loss: 0.0940 - val_accuracy: 0.9640
# Epoch 88/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1160 - accuracy: 0.9547 - val_loss: 0.1068 - val_accuracy: 0.9640
# Epoch 89/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1356 - accuracy: 0.9520 - val_loss: 0.0916 - val_accuracy: 0.9600
# Epoch 90/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1047 - accuracy: 0.9520 - val_loss: 0.0998 - val_accuracy: 0.9560
# Epoch 91/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1466 - accuracy: 0.9427 - val_loss: 0.1273 - val_accuracy: 0.9480
# Epoch 92/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1042 - accuracy: 0.9573 - val_loss: 0.1071 - val_accuracy: 0.9560
# Epoch 93/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1039 - accuracy: 0.9587 - val_loss: 0.1015 - val_accuracy: 0.9680
# Epoch 94/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1113 - accuracy: 0.9547 - val_loss: 0.1054 - val_accuracy: 0.9560
# Epoch 95/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1120 - accuracy: 0.9533 - val_loss: 0.0948 - val_accuracy: 0.9640
# Epoch 96/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0935 - accuracy: 0.9707 - val_loss: 0.0949 - val_accuracy: 0.9640
# Epoch 97/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0979 - accuracy: 0.9640 - val_loss: 0.0889 - val_accuracy: 0.9640
# Epoch 98/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0996 - accuracy: 0.9613 - val_loss: 0.0958 - val_accuracy: 0.9600
# Epoch 99/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0930 - accuracy: 0.9627 - val_loss: 0.0869 - val_accuracy: 0.9640
# Epoch 100/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0855 - accuracy: 0.9720 - val_loss: 0.1087 - val_accuracy: 0.9640
# Epoch 101/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1117 - accuracy: 0.9573 - val_loss: 0.0862 - val_accuracy: 0.9680
# Epoch 102/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1150 - accuracy: 0.9493 - val_loss: 0.1099 - val_accuracy: 0.9600
# Epoch 103/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0995 - accuracy: 0.9573 - val_loss: 0.0904 - val_accuracy: 0.9640
# Epoch 104/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1071 - accuracy: 0.9560 - val_loss: 0.0855 - val_accuracy: 0.9640
# Epoch 105/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1342 - accuracy: 0.9413 - val_loss: 0.0970 - val_accuracy: 0.9640
# Epoch 106/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0931 - accuracy: 0.9640 - val_loss: 0.0860 - val_accuracy: 0.9680
# Epoch 107/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.9680 - val_loss: 0.0840 - val_accuracy: 0.9680
# Epoch 108/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1017 - accuracy: 0.9587 - val_loss: 0.1135 - val_accuracy: 0.9560
# Epoch 109/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1478 - accuracy: 0.9413 - val_loss: 0.0974 - val_accuracy: 0.9600
# Epoch 110/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1217 - accuracy: 0.9547 - val_loss: 0.1131 - val_accuracy: 0.9440
# Epoch 111/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1063 - accuracy: 0.9600 - val_loss: 0.0866 - val_accuracy: 0.9680
# Epoch 112/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1076 - accuracy: 0.9547 - val_loss: 0.1047 - val_accuracy: 0.9520
# Epoch 113/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1005 - accuracy: 0.9613 - val_loss: 0.0867 - val_accuracy: 0.9640
# Epoch 114/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0963 - accuracy: 0.9693 - val_loss: 0.1043 - val_accuracy: 0.9640
# Epoch 115/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1469 - accuracy: 0.9360 - val_loss: 0.0860 - val_accuracy: 0.9600
# Epoch 116/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1346 - accuracy: 0.9440 - val_loss: 0.1058 - val_accuracy: 0.9600
# Epoch 117/200
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0774 - accuracy: 0.9627 - val_loss: 0.1072 - val_accuracy: 0.9640
# Epoch 118/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1051 - accuracy: 0.9493 - val_loss: 0.0960 - val_accuracy: 0.9640
# Epoch 119/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.9613 - val_loss: 0.1149 - val_accuracy: 0.9600
# Epoch 120/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1320 - accuracy: 0.9533 - val_loss: 0.0857 - val_accuracy: 0.9680
# Epoch 121/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1169 - accuracy: 0.9613 - val_loss: 0.1246 - val_accuracy: 0.9560
# Epoch 122/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1071 - accuracy: 0.9573 - val_loss: 0.1166 - val_accuracy: 0.9600
# Epoch 123/200
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1141 - accuracy: 0.9600 - val_loss: 0.0843 - val_accuracy: 0.9680
# Epoch 124/200
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1102 - accuracy: 0.9547 - val_loss: 0.0870 - val_accuracy: 0.9640
# Epoch 125/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1318 - accuracy: 0.9573 - val_loss: 0.0934 - val_accuracy: 0.9600
# Epoch 126/200
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0845 - accuracy: 0.9640 - val_loss: 0.0842 - val_accuracy: 0.9720
# Epoch 127/200
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1233 - accuracy: 0.9547 - val_loss: 0.1040 - val_accuracy: 0.9600

# %%
plt.figure()
plt.title("Learning curves")
plt.xlabel("Epoch")
plt.ylabel("Cross entropy loss")
plt.plot(history.history['loss'], label = 'train')
plt.plot(history.history['val_loss'], label = 'valid')
plt.legend()
plt.show()

# %%
plot_probabilities(ann2, X_moons, y_moons, colors, post_process=np.round)
# Out:
# 1172/1172 [==============================] - 2s 2ms/step

# %%
hidden = tf.keras.Sequential(ann2.layers[:-4])

fig, axes = plt.subplots(2, 2, figsize=(15, 15))

plot_probabilities(hidden, X_moons, y_moons, colors, ax=axes[0][0])
plot_probabilities(hidden, X_moons, y_moons, colors, dim=1, ax=axes[0][1])
plot_probabilities(hidden, X_moons, y_moons, colors, dim=2, ax=axes[1][0])
plot_probabilities(hidden, X_moons, y_moons, colors, dim=3, ax=axes[1][1])
# Out:
# 1172/1172 [==============================] - 2s 2ms/step
# 1172/1172 [==============================] - 2s 2ms/step
# 1172/1172 [==============================] - 2s 2ms/step
# 1172/1172 [==============================] - 2s 2ms/step

# %%
hidden = tf.keras.Sequential(ann2.layers[:-2])

fig, axes = plt.subplots(2, 2, figsize=(15, 15))

plot_probabilities(hidden, X_moons, y_moons, colors, ax=axes[0][0])
plot_probabilities(hidden, X_moons, y_moons, colors, dim=1, ax=axes[0][1])
plot_probabilities(hidden, X_moons, y_moons, colors, dim=2, ax=axes[1][0])
plot_probabilities(hidden, X_moons, y_moons, colors, dim=3, ax=axes[1][1])
# Out:
# 1172/1172 [==============================] - 2s 2ms/step
# 1172/1172 [==============================] - 2s 2ms/step
# 1172/1172 [==============================] - 2s 2ms/step
# 1172/1172 [==============================] - 2s 2ms/step
