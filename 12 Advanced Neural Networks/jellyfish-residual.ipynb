# %% [markdown]
# # Jellyfish species recognition using Residual units
#
# Importing all the data. Ignoring the suggested train/test/validation split to avoid overfitting on a particular dataset.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import os
import re

tf.random.set_seed(504)

image_paths = []
for dirname, _, filenames in os.walk('/kaggle/input/jellyfish-types'):
    for filename in filenames:
        image_paths.append(os.path.join(dirname, filename))

match_type = re.compile('.*/([^/]*)_jellyfish.*')
types = [match_type.match(path).group(1) for path in image_paths]
one_hot = pd.get_dummies(types, dtype=int)
labels = one_hot.columns
y = one_hot.to_numpy()

def load_image(path):
    content = tf.io.read_file(path)
    image = tf.io.decode_jpeg(content)
    scaled = tf.image.resize(image, size = (128, 128)) # To make sure all images have same size
    return tf.cast(scaled, tf.float32) / 255

X = np.array([load_image(path) for path in image_paths])
X.shape
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (1879, 128, 128, 3)

# %% [markdown]
# The network tends to overfit with only 1879 samples. In order to get more samples, some variations are added to the train and validation data. This helped. The random brightness seemed to do the most difference.
#
# Adding some variation with random noise add is worth a consideration.

# %%
def add_variations(X, y):
    def variations(int_image):
        flip_lr = tf.image.flip_left_right(int_image)
        flip_ud = tf.image.flip_up_down(int_image)
        img180 = tf.image.flip_up_down(flip_lr)
        return [int_image, flip_lr, flip_ud, img180, 
                tf.image.random_brightness(int_image, .1)]
    
    x_element_shape = X.shape[1:]
    y_element_shape = y.shape[1:]
    
    X = np.array([variations(x) for x in X])
    y = np.array([np.full((X.shape[1], *v.shape), v) for v in y])
    
    return X.reshape([-1, *x_element_shape]), y.reshape(-1, *y_element_shape)

    
X_, X_test, y_, y_test = train_test_split(X, y, random_state=504)
X_train, X_valid, y_train, y_valid = train_test_split(X_, y_, random_state=504)
X_train, y_train = add_variations(X_train, y_train)

# %% [markdown]
# ## The Network
# Let's first define a residual unit.

# %%
class ResidualUnit(tf.keras.layers.Layer):
    def __init__(self, filters, kernel_size, strides=1, activation="relu", dropout=0.0, **kwargs):
        super().__init__(**kwargs)
        self.activation = tf.keras.activations.get(activation)
        self.main_path = tf.keras.models.Sequential()
        self.main_path.add(layers.Conv2D(filters, kernel_size, strides=strides, padding="same", kernel_initializer="he_normal"))
        if dropout > 0:
            self.main_path.add(layers.SpatialDropout2D(dropout))
        self.main_path.add(layers.BatchNormalization())
        self.main_path.add(layers.Activation(self.activation))
        self.main_path.add(layers.Conv2D(filters, kernel_size, strides=1, padding="same", kernel_initializer="he_normal"))
        if dropout > 0:
            self.main_path.add(layers.SpatialDropout2D(dropout))
        self.main_path.add(layers.BatchNormalization())
        self.skip_path = tf.keras.models.Sequential()
        if strides > 1:
            self.skip_path.add(layers.Conv2D(filters, 1, strides=strides, padding="same", kernel_initializer="he_normal"))
            if dropout > 0:
                self.skip_path.add(layers.SpatialDropout2D(dropout))
            self.skip_path.add(layers.BatchNormalization())
            
    def call(self, inputs):
        Z = self.main_path(inputs)
        skip_Z = self.skip_path(inputs)
        return self.activation(Z + skip_Z)

# %%
cnn = tf.keras.models.Sequential([
    layers.Input(X_train.shape[1:]),
    layers.Conv2D(16, 7, activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(3, 3)),
    ResidualUnit(16, 3),
    ResidualUnit(16, 3),
    ResidualUnit(32, 3, strides = 2),
    ResidualUnit(64, 3, strides = 2, dropout = .25),
    ResidualUnit(128, 3, strides = 2, dropout = .5),
    layers.GlobalAveragePooling2D(),
    layers.Dense(units=y.shape[1], activation='softmax')
])

cnn.compile(loss = 'categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), metrics = ['accuracy'])
cnn.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      2368
#
#  batch_normalization (BatchN  (None, 128, 128, 16)     64
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 42, 42, 16)       0
#  )
#
#  residual_unit (ResidualUnit  (None, 42, 42, 16)       4768
#  )
#
#  residual_unit_1 (ResidualUn  (None, 42, 42, 16)       4768
#  it)
#
#  residual_unit_2 (ResidualUn  (None, 21, 21, 32)       14816
#  it)
#
#  residual_unit_3 (ResidualUn  (None, 11, 11, 64)       58304
#  it)
#
#  residual_unit_4 (ResidualUn  (None, 6, 6, 128)        231296
#  it)
#
#  global_average_pooling2d (G  (None, 128)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 6)                 774
#
# =================================================================
# Total params: 317,158
# Trainable params: 315,654
# Non-trainable params: 1,504
# _________________________________________________________________

# %% [markdown]
# Sooner or later the network overfits, so it's good to use early stopping.
#
# I always prefer val_loss as the monitor. If we use val_accuracy we risk overfitting the validation data. 'loss' and 'accuracy' are quite meaningless here.

# %%
es = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience = 20, restore_best_weights=True)

history = cnn.fit(X_train, y_train, 
                  epochs = 200, 
                  validation_data = (X_valid, y_valid),
                  callbacks=[es])
# Out:
# Epoch 1/200
# 2023-10-29 05:52:48.329715: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_10/residual_unit_3/sequential_6/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 165/165 [==============================] - 25s 29ms/step - loss: 1.6050 - accuracy: 0.3438 - val_loss: 2.0369 - val_accuracy: 0.2323
# Epoch 2/200
# 165/165 [==============================] - 4s 24ms/step - loss: 1.3300 - accuracy: 0.4706 - val_loss: 1.8474 - val_accuracy: 0.3286
# Epoch 3/200
# 165/165 [==============================] - 4s 24ms/step - loss: 1.1515 - accuracy: 0.5542 - val_loss: 1.5882 - val_accuracy: 0.4249
# Epoch 4/200
# 165/165 [==============================] - 4s 24ms/step - loss: 1.0639 - accuracy: 0.5953 - val_loss: 1.6341 - val_accuracy: 0.4731
# Epoch 5/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.9657 - accuracy: 0.6388 - val_loss: 1.1357 - val_accuracy: 0.5552
# Epoch 6/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.8569 - accuracy: 0.6862 - val_loss: 1.0264 - val_accuracy: 0.6091
# Epoch 7/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.7847 - accuracy: 0.7121 - val_loss: 1.0521 - val_accuracy: 0.5666
# Epoch 8/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.6996 - accuracy: 0.7532 - val_loss: 0.9292 - val_accuracy: 0.6544
# Epoch 9/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.6486 - accuracy: 0.7691 - val_loss: 1.3833 - val_accuracy: 0.5241
# Epoch 10/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.6001 - accuracy: 0.7858 - val_loss: 0.8665 - val_accuracy: 0.6941
# Epoch 11/200
# 165/165 [==============================] - 4s 25ms/step - loss: 0.5589 - accuracy: 0.7994 - val_loss: 0.5968 - val_accuracy: 0.8187
# Epoch 12/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.5182 - accuracy: 0.8129 - val_loss: 0.8680 - val_accuracy: 0.7450
# Epoch 13/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.4664 - accuracy: 0.8320 - val_loss: 1.2537 - val_accuracy: 0.6487
# Epoch 14/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.4486 - accuracy: 0.8394 - val_loss: 0.5295 - val_accuracy: 0.8357
# Epoch 15/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.4198 - accuracy: 0.8568 - val_loss: 1.0074 - val_accuracy: 0.6516
# Epoch 16/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.4098 - accuracy: 0.8598 - val_loss: 0.8151 - val_accuracy: 0.7875
# Epoch 17/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.3477 - accuracy: 0.8803 - val_loss: 0.6594 - val_accuracy: 0.8527
# Epoch 18/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.3383 - accuracy: 0.8790 - val_loss: 0.5527 - val_accuracy: 0.8385
# Epoch 19/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.3233 - accuracy: 0.8922 - val_loss: 0.6432 - val_accuracy: 0.8272
# Epoch 20/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.2951 - accuracy: 0.8992 - val_loss: 0.4787 - val_accuracy: 0.8725
# Epoch 21/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.2597 - accuracy: 0.9125 - val_loss: 0.5041 - val_accuracy: 0.8612
# Epoch 22/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.2946 - accuracy: 0.8964 - val_loss: 0.4435 - val_accuracy: 0.8924
# Epoch 23/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.2218 - accuracy: 0.9288 - val_loss: 0.3929 - val_accuracy: 0.8895
# Epoch 24/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.2328 - accuracy: 0.9146 - val_loss: 0.5223 - val_accuracy: 0.8782
# Epoch 25/200
# 165/165 [==============================] - 4s 25ms/step - loss: 0.2115 - accuracy: 0.9290 - val_loss: 0.8614 - val_accuracy: 0.8244
# Epoch 26/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.2186 - accuracy: 0.9295 - val_loss: 0.5561 - val_accuracy: 0.8555
# Epoch 27/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.2069 - accuracy: 0.9339 - val_loss: 0.6274 - val_accuracy: 0.8414
# Epoch 28/200
# 165/165 [==============================] - 4s 25ms/step - loss: 0.1692 - accuracy: 0.9400 - val_loss: 0.3817 - val_accuracy: 0.9178
# Epoch 29/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1615 - accuracy: 0.9479 - val_loss: 1.4496 - val_accuracy: 0.6856
# Epoch 30/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1676 - accuracy: 0.9419 - val_loss: 1.1648 - val_accuracy: 0.7904
# Epoch 31/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1756 - accuracy: 0.9403 - val_loss: 0.4384 - val_accuracy: 0.8980
# Epoch 32/200
# 165/165 [==============================] - 4s 25ms/step - loss: 0.1687 - accuracy: 0.9443 - val_loss: 0.7194 - val_accuracy: 0.8074
# Epoch 33/200
# 165/165 [==============================] - 4s 25ms/step - loss: 0.1610 - accuracy: 0.9455 - val_loss: 0.7356 - val_accuracy: 0.8470
# Epoch 34/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1450 - accuracy: 0.9528 - val_loss: 0.4576 - val_accuracy: 0.9150
# Epoch 35/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1404 - accuracy: 0.9532 - val_loss: 0.5822 - val_accuracy: 0.8527
# Epoch 36/200
# 165/165 [==============================] - 4s 25ms/step - loss: 0.1555 - accuracy: 0.9473 - val_loss: 0.3408 - val_accuracy: 0.9405
# Epoch 37/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1240 - accuracy: 0.9555 - val_loss: 0.3990 - val_accuracy: 0.9093
# Epoch 38/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1333 - accuracy: 0.9580 - val_loss: 0.4271 - val_accuracy: 0.9263
# Epoch 39/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1311 - accuracy: 0.9563 - val_loss: 0.4619 - val_accuracy: 0.9065
# Epoch 40/200
# 165/165 [==============================] - 4s 25ms/step - loss: 0.1147 - accuracy: 0.9591 - val_loss: 0.5097 - val_accuracy: 0.9122
# Epoch 41/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1026 - accuracy: 0.9648 - val_loss: 0.4816 - val_accuracy: 0.9207
# Epoch 42/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0968 - accuracy: 0.9676 - val_loss: 0.9753 - val_accuracy: 0.7535
# Epoch 43/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1007 - accuracy: 0.9663 - val_loss: 0.3769 - val_accuracy: 0.9263
# Epoch 44/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1273 - accuracy: 0.9606 - val_loss: 0.7697 - val_accuracy: 0.8272
# Epoch 45/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1189 - accuracy: 0.9616 - val_loss: 0.4819 - val_accuracy: 0.9150
# Epoch 46/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1156 - accuracy: 0.9634 - val_loss: 0.5845 - val_accuracy: 0.8697
# Epoch 47/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0957 - accuracy: 0.9689 - val_loss: 0.6041 - val_accuracy: 0.8895
# Epoch 48/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0890 - accuracy: 0.9733 - val_loss: 0.4120 - val_accuracy: 0.9207
# Epoch 49/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0828 - accuracy: 0.9723 - val_loss: 0.3869 - val_accuracy: 0.9462
# Epoch 50/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.1190 - accuracy: 0.9614 - val_loss: 2.6285 - val_accuracy: 0.6657
# Epoch 51/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0929 - accuracy: 0.9693 - val_loss: 0.4380 - val_accuracy: 0.9263
# Epoch 52/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0946 - accuracy: 0.9703 - val_loss: 0.3599 - val_accuracy: 0.9377
# Epoch 53/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0950 - accuracy: 0.9684 - val_loss: 0.5226 - val_accuracy: 0.9207
# Epoch 54/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0917 - accuracy: 0.9674 - val_loss: 0.4974 - val_accuracy: 0.9065
# Epoch 55/200
# 165/165 [==============================] - 4s 24ms/step - loss: 0.0848 - accuracy: 0.9723 - val_loss: 0.4900 - val_accuracy: 0.9207
# Epoch 56/200
# 165/165 [==============================] - 4s 25ms/step - loss: 0.0713 - accuracy: 0.9769 - val_loss: 0.4415 - val_accuracy: 0.9292

# %% [markdown]
# ## The outcome
#
# We see the overfitting clearly below.

# %%
figure = plt.figure(figsize=(20, 10))
ax = figure.add_subplot(1, 2, 1, title='Learning curves (loss)')
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.plot(history.history['loss'], label = 'train')
ax.plot(history.history['val_loss'], label = 'valid')
ax.legend()

ax = figure.add_subplot(1, 2, 2, title='Learning curves (accuracy)')
ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy")
ax.plot(history.history['accuracy'], label = 'train')
ax.plot(history.history['val_accuracy'], label = 'valid')
ax.legend()

plt.show()

# %% [markdown]
# The final result is okay. Though no better than the basic convolutional network.

# %%
train_eval = cnn.evaluate(X_train, y_train)
validation_eval = cnn.evaluate(X_valid, y_valid)
test_eval = cnn.evaluate(X_test, y_test)
print("Error on test data: {p:.2f}%".format(p = 100*(1-test_eval[1])))
# Out:
# 165/165 [==============================] - 1s 8ms/step - loss: 0.0751 - accuracy: 0.9758
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3408 - accuracy: 0.9405
# 15/15 [==============================] - 0s 26ms/step - loss: 0.2811 - accuracy: 0.9426
# Error on test data: 5.74%
