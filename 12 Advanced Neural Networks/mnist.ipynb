# %%
import tensorflow as tf
from tensorflow.keras import layers

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt


import numpy as np
from numpy.random import seed, randint

# %%
seed(504)
tf.random.set_seed(504)

# %% [markdown]
# # Getting the data

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', as_frame=False)
X, y = mnist.data.reshape(-1, 28, 28, 1), tf.keras.utils.to_categorical(mnist.target)
X_train, y_train = X[:60_000], y[:60_000]
X_test, y_test = X[60_000:], y[60_000:]
# Out:
# c:\Users\oih\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\datasets\_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %% [markdown]
# # Training the neural network

# %%
X.shape
# Out:
# (70000, 28, 28, 1)

# %%
es = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 10, restore_best_weights=True)

cnn = tf.keras.models.Sequential([
    layers.Conv2D(16, 3, activation='relu', padding='same', input_shape=X_train[0].shape),
    layers.Dropout(.4),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu', padding='same'),
    layers.Dropout(.4),
    layers.MaxPooling2D(),
    layers.Conv2D(120, 3, activation='relu', padding='same'),
    layers.Dropout(.4),
    layers.Flatten(),
    layers.Dense(units=84, activation='relu'),
    layers.Dropout(.4),
    layers.Dense(units=10, activation='softmax')
])
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  dropout (Dropout)           (None, 28, 28, 16)        0
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        4640
#
#  dropout_1 (Dropout)         (None, 14, 14, 32)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 120)         34680
#
#  dropout_2 (Dropout)         (None, 7, 7, 120)         0
#
#  flatten (Flatten)           (None, 5880)              0
#
#  dense (Dense)               (None, 84)                494004
#
#  dropout_3 (Dropout)         (None, 84)                0
#
#  dense_1 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 534334 (2.04 MB)
# Trainable params: 534334 (2.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
cnn.compile(loss = 'categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(learning_rate = 0.0001), metrics = ['accuracy'])

history = cnn.fit(X_train, y_train, 
                    epochs = 100, 
                    validation_split = 0.2,
                    callbacks=[es])
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 40s 25ms/step - loss: 2.7698 - accuracy: 0.2576 - val_loss: 1.5577 - val_accuracy: 0.4678
# Epoch 2/100
# 1500/1500 [==============================] - 37s 25ms/step - loss: 1.6181 - accuracy: 0.4213 - val_loss: 1.0167 - val_accuracy: 0.7536
# Epoch 3/100
# 1500/1500 [==============================] - 37s 25ms/step - loss: 1.0435 - accuracy: 0.6533 - val_loss: 0.4503 - val_accuracy: 0.9234
# Epoch 4/100
# 1500/1500 [==============================] - 37s 25ms/step - loss: 0.6130 - accuracy: 0.8100 - val_loss: 0.2141 - val_accuracy: 0.9597
# Epoch 5/100
# 1500/1500 [==============================] - 37s 25ms/step - loss: 0.4070 - accuracy: 0.8784 - val_loss: 0.1499 - val_accuracy: 0.9683
# Epoch 6/100
# 1500/1500 [==============================] - 37s 25ms/step - loss: 0.3018 - accuracy: 0.9125 - val_loss: 0.1082 - val_accuracy: 0.9761
# Epoch 7/100
# 1500/1500 [==============================] - 70s 47ms/step - loss: 0.2407 - accuracy: 0.9307 - val_loss: 0.1027 - val_accuracy: 0.9775
# Epoch 8/100
# 1500/1500 [==============================] - 67s 44ms/step - loss: 0.2047 - accuracy: 0.9411 - val_loss: 0.0815 - val_accuracy: 0.9822
# Epoch 9/100
# 1500/1500 [==============================] - 41s 27ms/step - loss: 0.1764 - accuracy: 0.9492 - val_loss: 0.0753 - val_accuracy: 0.9838
# Epoch 10/100
# 1500/1500 [==============================] - 75s 50ms/step - loss: 0.1583 - accuracy: 0.9558 - val_loss: 0.0676 - val_accuracy: 0.9849
# Epoch 11/100
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.1399 - accuracy: 0.9606 - val_loss: 0.0650 - val_accuracy: 0.9856
# Epoch 12/100
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.1245 - accuracy: 0.9650 - val_loss: 0.0571 - val_accuracy: 0.9870
# Epoch 13/100
# 1500/1500 [==============================] - 43s 29ms/step - loss: 0.1148 - accuracy: 0.9681 - val_loss: 0.0599 - val_accuracy: 0.9858
# Epoch 14/100
# 1500/1500 [==============================] - 40s 27ms/step - loss: 0.1038 - accuracy: 0.9713 - val_loss: 0.0536 - val_accuracy: 0.9876
# Epoch 15/100
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0991 - accuracy: 0.9719 - val_loss: 0.0508 - val_accuracy: 0.9885
# Epoch 16/100
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0958 - accuracy: 0.9733 - val_loss: 0.0499 - val_accuracy: 0.9891
# Epoch 17/100
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0895 - accuracy: 0.9762 - val_loss: 0.0442 - val_accuracy: 0.9897
# Epoch 18/100
# 1500/1500 [==============================] - 38s 26ms/step - loss: 0.0835 - accuracy: 0.9768 - val_loss: 0.0421 - val_accuracy: 0.9908
# Epoch 19/100
# 1500/1500 [==============================] - 41s 27ms/step - loss: 0.0783 - accuracy: 0.9782 - val_loss: 0.0420 - val_accuracy: 0.9897
# Epoch 20/100
# 1500/1500 [==============================] - 42s 28ms/step - loss: 0.0757 - accuracy: 0.9791 - val_loss: 0.0441 - val_accuracy: 0.9890
# Epoch 21/100
# 1500/1500 [==============================] - 447s 298ms/step - loss: 0.0705 - accuracy: 0.9801 - val_loss: 0.0413 - val_accuracy: 0.9901
# Epoch 22/100
# 1500/1500 [==============================] - 40s 27ms/step - loss: 0.0694 - accuracy: 0.9809 - val_loss: 0.0450 - val_accuracy: 0.9901
# Epoch 23/100
# 1500/1500 [==============================] - 39s 26ms/step - loss: 0.0650 - accuracy: 0.9813 - val_loss: 0.0389 - val_accuracy: 0.9908
# Epoch 24/100
# 1500/1500 [==============================] - 38s 25ms/step - loss: 0.0647 - accuracy: 0.9822 - val_loss: 0.0374 - val_accuracy: 0.9910
# Epoch 25/100
# 1500/1500 [==============================] - 27s 18ms/step - loss: 0.0620 - accuracy: 0.9827 - val_loss: 0.0392 - val_accuracy: 0.9902
# Epoch 26/100
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0625 - accuracy: 0.9824 - val_loss: 0.0404 - val_accuracy: 0.9912
# Epoch 27/100
# 1500/1500 [==============================] - 27s 18ms/step - loss: 0.0580 - accuracy: 0.9835 - val_loss: 0.0400 - val_accuracy: 0.9915
# Epoch 28/100
# 1500/1500 [==============================] - 27s 18ms/step - loss: 0.0544 - accuracy: 0.9844 - val_loss: 0.0373 - val_accuracy: 0.9910
# Epoch 29/100
# 1500/1500 [==============================] - 28s 19ms/step - loss: 0.0550 - accuracy: 0.9843 - val_loss: 0.0381 - val_accuracy: 0.9898
# Epoch 30/100
# 1500/1500 [==============================] - 27s 18ms/step - loss: 0.0510 - accuracy: 0.9857 - val_loss: 0.0373 - val_accuracy: 0.9901
# Epoch 31/100
# 1500/1500 [==============================] - 32s 22ms/step - loss: 0.0495 - accuracy: 0.9856 - val_loss: 0.0348 - val_accuracy: 0.9924
# Epoch 32/100
# 1500/1500 [==============================] - 200s 133ms/step - loss: 0.0494 - accuracy: 0.9856 - val_loss: 0.0354 - val_accuracy: 0.9908
# Epoch 33/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0488 - accuracy: 0.9861 - val_loss: 0.0344 - val_accuracy: 0.9914
# Epoch 34/100
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.0491 - accuracy: 0.9863 - val_loss: 0.0397 - val_accuracy: 0.9920
# Epoch 35/100
# 1500/1500 [==============================] - 26s 18ms/step - loss: 0.0450 - accuracy: 0.9870 - val_loss: 0.0362 - val_accuracy: 0.9913
# Epoch 36/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0435 - accuracy: 0.9873 - val_loss: 0.0341 - val_accuracy: 0.9916
# Epoch 37/100
# 1500/1500 [==============================] - 27s 18ms/step - loss: 0.0413 - accuracy: 0.9880 - val_loss: 0.0332 - val_accuracy: 0.9918
# Epoch 38/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0434 - accuracy: 0.9876 - val_loss: 0.0331 - val_accuracy: 0.9921
# Epoch 39/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0417 - accuracy: 0.9875 - val_loss: 0.0328 - val_accuracy: 0.9927
# Epoch 40/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0423 - accuracy: 0.9879 - val_loss: 0.0304 - val_accuracy: 0.9922
# Epoch 41/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0405 - accuracy: 0.9885 - val_loss: 0.0328 - val_accuracy: 0.9930
# Epoch 42/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0379 - accuracy: 0.9891 - val_loss: 0.0338 - val_accuracy: 0.9922
# Epoch 43/100
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.0380 - accuracy: 0.9889 - val_loss: 0.0285 - val_accuracy: 0.9933
# Epoch 44/100
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.0362 - accuracy: 0.9895 - val_loss: 0.0306 - val_accuracy: 0.9923
# Epoch 45/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0381 - accuracy: 0.9892 - val_loss: 0.0319 - val_accuracy: 0.9923
# Epoch 46/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0348 - accuracy: 0.9902 - val_loss: 0.0296 - val_accuracy: 0.9928
# Epoch 47/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0358 - accuracy: 0.9897 - val_loss: 0.0302 - val_accuracy: 0.9926
# Epoch 48/100
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.0339 - accuracy: 0.9901 - val_loss: 0.0307 - val_accuracy: 0.9927
# Epoch 49/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0351 - accuracy: 0.9899 - val_loss: 0.0318 - val_accuracy: 0.9918
# Epoch 50/100
# 1500/1500 [==============================] - 25s 16ms/step - loss: 0.0330 - accuracy: 0.9909 - val_loss: 0.0316 - val_accuracy: 0.9925
# Epoch 51/100
# 1500/1500 [==============================] - 25s 17ms/step - loss: 0.0331 - accuracy: 0.9910 - val_loss: 0.0307 - val_accuracy: 0.9923
# Epoch 52/100
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0317 - accuracy: 0.9906 - val_loss: 0.0320 - val_accuracy: 0.9923
# Epoch 53/100
# 1500/1500 [==============================] - 26s 17ms/step - loss: 0.0324 - accuracy: 0.9905 - val_loss: 0.0293 - val_accuracy: 0.9926

# %%
figure = plt.figure(figsize=(20, 10))
ax = figure.add_subplot(1, 2, 1, title='Learning curves (loss)')
ax.set_xlabel("Epoch")
ax.set_ylabel("Loss")
ax.plot(history.history['loss'], label = 'train')
ax.plot(history.history['val_loss'], label = 'valid')
ax.legend()

ax = figure.add_subplot(1, 2, 2, title='Learning curves (accuracy)')
ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy")
ax.plot(history.history['accuracy'], label = 'train')
ax.plot(history.history['val_accuracy'], label = 'valid')
ax.legend()

plt.show()

# %%
train_eval = cnn.evaluate(X_train[:48000], y_train[:48000])
validation_eval = cnn.evaluate(X_train[48000:], y_train[48000:])
test_eval = cnn.evaluate(X_test, y_test)
print("On train data: Loss = {loss:.4f}, accuracy = {accuracy:.4f}".format(loss=train_eval[0], accuracy=train_eval[1]))
print("On validation data: Loss = {loss:.4f}, accuracy = {accuracy:.4f}".format(loss=validation_eval[0], accuracy=validation_eval[1]))
print("On test data: Loss = {loss:.4f}, accuracy = {accuracy:.4f}".format(loss=test_eval[0], accuracy=test_eval[1]))
print("Error on test data: {p:.2f}%".format(p = 100*(1-test_eval[1])))
# Out:
# 1500/1500 [==============================] - 7s 4ms/step - loss: 0.0119 - accuracy: 0.9984
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0285 - accuracy: 0.9933
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0241 - accuracy: 0.9924
# On train data: Loss = 0.0119, accuracy = 0.9984
# On validation data: Loss = 0.0285, accuracy = 0.9933
# On test data: Loss = 0.0241, accuracy = 0.9924
# Error on test data: 0.76%

# %%
from plot_utils import grid_plot
from matplotlib.colors import CenteredNorm

kernel_weights = cnn.layers[0].weights[0]
kernel_shape = kernel_weights.shape[:2]
kernels = [kernel_weights[:, :, :, i].numpy().reshape(kernel_shape) for i in range(kernel_weights.shape[-1])]

def plot_kernel(ax, kernel, index):
    ax.axis('off')
    ax.imshow(kernel, cmap='coolwarm', norm=CenteredNorm())

grid_plot(kernels, 4, 4, plot_kernel, figsize=(5, 5))
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# # Consider misclassified digits

# %%
probabilities = np.array(cnn.predict(X_test))
predictions = np.argmax(probabilities, axis = 1) #what does the model predict
labels = np.argmax(y_test, axis = 1) #what are the actual labels
misclas_idxs = np.argwhere(predictions != labels).reshape(-1)

idxs = [misclas_idxs[randint(low = 0, high = len(misclas_idxs) - 1)] for i in range(9)] #choose 9 random indeces

figure = plt.figure(figsize=(15, 15))
for i in range(9):
    idx = idxs[i]
    ax = figure.add_subplot(3, 3, i + 1, title='expected: {}, predicted: {}'.format(labels[idx], predictions[idx]))
    ax.axis('off')
    ax.imshow(np.reshape(X_test[idx], (28, 28)), cmap='Greys')
# Out:
# 313/313 [==============================] - 1s 4ms/step
